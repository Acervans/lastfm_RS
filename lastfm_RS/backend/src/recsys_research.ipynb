# %%
from constants import *
from sqlalchemy import create_engine, inspect, text, func, MetaData, select, Table
from sqlalchemy.orm import sessionmaker

db = create_engine(
    "postgresql://alumnodb:alumnodb@localhost:5432/lastfm_db", client_encoding="UTF-8")

metadata = MetaData()
metadata.reflect(bind=db)

# %%
def table(name) -> Table:
    return metadata.tables[name]

Tag = table('tag')
Album = table('album')
Artist = table('artist')
Track = table('track')
User = table('user_')

AlbumTags = table('albumtoptags')
ArtistTags = table('artisttoptags')
TrackTags = table('tracktoptags')
UserTags = table('usertoptracks') # Empty, use most frequent?

UserTopAlbums = table('usertopalbums')
UserTopArtists = table('usertopartists')
UserTopTracks = table('usertoptracks')

UserRecentTracks = table('userrecenttracks')
UserLovedTracks = table('userlovedtracks')

# %%
session = sessionmaker(db)

"""
select * from tracktoptags tt join track on track.id = tt.track_id join tag on tag.id = tt.tag_id where tag.name ilike 'vaporwave' order by track.id;
"""
with session.begin() as s:
    display(s.query(TrackTags, Track.c.name)
            .join(Tag, Tag.c.id == TrackTags.c.tag_id)
            .join(Track, Track.c.id == TrackTags.c.track_id)
            .filter(Tag.c.name.ilike('vaporwave'))
            .order_by(Track.c.id).all())
# Out:
# [(402, 191613, 2, 'METAMATERIAL'),
#  (2538, 191613, 1, 'Come Back Down'),
#  (4120, 191613, 5, '発見'),
#  (4539, 191613, 4, '上昇'),
#  (6302, 191613, 4, 'あなたと一人で数分'),
#  (9765, 191613, 1, 'Warmpop'),
#  (10821, 191613, 1, 'Gonna Dream 2nite.'),
#  (10829, 191613, 3, 'Ecco Chamber'),
#  (11415, 191613, 7, 'Better'),
#  (11523, 191613, 7, '着物'),
#  (12124, 191613, 6, 'Beam of Love'),
#  (13812, 191613, 5, 'James Joint'),
#  (14444, 191613, 7, 'Otra Noche en Miami'),
#  (19642, 191613, 4, "Can't You See"),
#  (20054, 191613, 1, '熱帯雨林 Plaza'),
#  (23754, 191613, 4, 'いつも'),
#  (31485, 191613, 1, '痴心妄想'),
#  (36811, 191613, 6, 'バウンス家の中でセックス'),
#  (41632, 191613, 1, '銀'),
#  (41884, 191613, 9, 'KΞΞP/////THIS/////'),
#  (45684, 191613, 3, 'The Setup'),
#  (62806, 191613, 2, 'Bow Ecco'),
#  (69439, 191613, 5, 'ＴＥＭＰＴＡＴＩＯＮ 私はあなたが欲しいんだよ'),
#  (70692, 191613, 4, 'PURITY BOYS'),
#  (73881, 191613, 1, 'Miss Macross'),
#  (74206, 191613, 1, 'chinese food takeaway'),
#  (75726, 191613, 4, 'Resonance'),
#  (75996, 191613, 4, 'Iced Cooly Beatnik'),
#  (76551, 191613, 1, 'Before The Rain'),
#  (80942, 191613, 2, 'Hush'),
#  (84585, 191613, 2, '水TEMPLES'),
#  (86782, 191613, 1, '遠くの愛好家'),
#  (88805, 191613, 7, 'Nine-rubber Wisdom'),
#  (91339, 191613, 1, 'She'),
#  (91666, 191613, 1, 'StayTheNight'),
#  (91701, 191613, 1, 'Saturday Night'),
#  (93901, 191613, 4, '東京，  ２０８９'),
#  (94462, 191613, 3, 'Skylar Spence'),
#  (96235, 191613, 1, 'Metal Rain'),
#  (101150, 191613, 1, 'Private Caller'),
#  (101871, 191613, 7, 'あなたは私の空想です'),
#  (103864, 191613, 3, 'Hit The Spot'),
#  (108556, 191613, 1, 'Occasional Flames'),
#  (111223, 191613, 1, 'mall madness'),
#  (113111, 191613, 1, '表面張力'),
#  (117072, 191613, 1, 'daydream'),
#  (120768, 191613, 2, 'Vaping in the Hood'),
#  (125965, 191613, 6, "Luxury's Fortune"),
#  (129618, 191613, 2, 'C3L3STIAL_CITY'),
#  (135652, 191613, 5, '遠い思い出'),
#  (138115, 191613, 5, 'ブート'),
#  (140084, 191613, 3, 'ハーモニー'),
#  (141066, 191613, 3, 'あなたは私の心にいつもしている'),
#  (153263, 191613, 5, 'Horsey (feat. Sarah Bonito)'),
#  (156010, 191613, 5, '海側恋人'),
#  (157599, 191613, 1, 'Breezem Out'),
#  (157711, 191613, 2, 'パーティーの日！'),
#  (161444, 191613, 5, 'Together'),
#  (162020, 191613, 5, 'Horsey (feat. Sarah Bonito)'),
#  (165528, 191613, 4, 'テレコミュニケーション'),
#  (165536, 191613, 4, '親密'),
#  (176757, 191613, 1, 'The Law'),
#  (179537, 191613, 1, 'Night In Tokyo Pt. II'),
#  (185585, 191613, 1, 'RotatingBed'),
#  (185736, 191613, 6, 'Lipslap'),
#  (188144, 191613, 7, 'アトラクション'),
#  (188351, 191613, 4, 'あなたを待って'),
#  (190198, 191613, 9, 'Teen Pregnancy'),
#  (190797, 191613, 6, 'Cherry Pepsi'),
#  (195283, 191613, 5, '808 Dreams'),
#  (195354, 191613, 5, 'Out of Time'),
#  (198496, 191613, 1, 'shadows'),
#  (201693, 191613, 1, 'Count What You Have Now'),
#  (204787, 191613, 1, 'Lost But Never Alone'),
#  (205410, 191613, 3, '午後11時 The 11pm'),
#  (207871, 191613, 6, 'DAM! DAM! DAM!'),
#  (211547, 191613, 4, 'midnight'),
#  (211903, 191613, 6, 'Private Caller'),
#  (214059, 191613, 2, 'Beach Walk'),
#  (216483, 191613, 1, 'On The Way Out'),
#  (216537, 191613, 3, '表面の下に愛'),
#  (216789, 191613, 2, 'Wake Up'),
#  (218566, 191613, 6, '心合成'),
#  (220074, 191613, 3, '真の姿'),
#  (221875, 191613, 7, '5D'),
#  (223876, 191613, 1, '再びお会い'),
#  (224665, 191613, 3, 'DUFF HUSTER'),
#  (227188, 191613, 4, 'ECCOと悪寒ダイビング'),
#  (230715, 191613, 1, '真正的爱情'),
#  (231740, 191613, 1, 'naga - SHES DIFFERENT IN FLASH'),
#  (233082, 191613, 1, 'Bitter Turns To Sugar'),
#  (234714, 191613, 2, '孤独な夜'),
#  (234789, 191613, 5, '終わりのない愛'),
#  (236862, 191613, 3, '花の専門店'),
#  (239090, 191613, 2, 'HOTEL TAIWAN WELC☯MES U'),
#  (242058, 191613, 8, 'WAVESTEP'),
#  (242655, 191613, 3, 'Loft バルコニー'),
#  (246616, 191613, 4, '停電'),
#  (247002, 191613, 5, 'リサフランク420 / 現代のコンピュー'),
#  (247606, 191613, 4, 'Emerald Hill Zone 2'),
#  (249398, 191613, 5, '最後の抱擁'),
#  (251223, 191613, 1, 'A4'),
#  (253632, 191613, 1, 'Somber Waves'),
#  (255709, 191613, 1, 'ふわっと'),
#  (257987, 191613, 1, 'Nobody Here'),
#  (258652, 191613, 5, 'Hit Vibes'),
#  (259656, 191613, 1, 'Aerobic Workout 95'),
#  (261043, 191613, 9, 'Options'),
#  (264316, 191613, 1, 'Deep Swim'),
#  (272659, 191613, 7, '愛の多くの顔'),
#  (272765, 191613, 4, '新宿ゴールデン街'),
#  (272983, 191613, 7, 'AKAIWA 1985'),
#  (276226, 191613, 1, 'Us'),
#  (276332, 191613, 7, 'Contagious'),
#  (283150, 191613, 1, "ain't nobody like you"),
#  (289529, 191613, 7, 'あなたの世界'),
#  (296137, 191613, 2, 'Fun Tonight'),
#  (296532, 191613, 3, "I'm That Guy"),
#  (298929, 191613, 1, "Pretty Girls i Don't Know Anymore"),
#  (304601, 191613, 2, 'Midnight Caller'),
#  (305838, 191613, 1, '輝き'),
#  (305922, 191613, 1, 'Misery Loves'),
#  (306757, 191613, 4, 'pizza day'),
#  (310776, 191613, 1, 'Bez ciśnień - Lech Music 2020'),
#  (311324, 191613, 6, '星間性交'),
#  (311869, 191613, 3, 'Cerulean'),
#  (312731, 191613, 1, 'SAINT PEPSI - ENJOY YOURSELF'),
#  (312815, 191613, 3, '私はあなたのことを思っている'),
#  (314049, 191613, 1, 'LSD Polyphony'),
#  (314639, 191613, 5, 'NAKANO BOTANICAL GARDENS'),
#  (315408, 191613, 2, 'SimpsonWave1995'),
#  (320980, 191613, 7, '遠くの愛好家'),
#  (321840, 191613, 1, 'Beat Street'),
#  (327531, 191613, 4, 'プランジ'),
#  (330308, 191613, 6, 'いつもそこに私のために'),
#  (331690, 191613, 6, '存在'),
#  (332142, 191613, 2, 'Lost Dreams'),
#  (332728, 191613, 2, 'leo'),
#  (335373, 191613, 5, 'Freeze'),
#  (336605, 191613, 6, 'Implanted Memories'),
#  (339139, 191613, 2, "Don't Kiss Me While i'm Swimming"),
#  (342788, 191613, 3, 'Anxiety Online !'),
#  (346922, 191613, 6, '断線'),
#  (350662, 191613, 1, 'Give It to Me'),
#  (351006, 191613, 5, 'あなたを残す'),
#  (356824, 191613, 1, 'island'),
#  (360784, 191613, 4, 'BIOS'),
#  (363850, 191613, 1, '50//50'),
#  (366787, 191613, 4, '光る目'),
#  (367857, 191613, 1, 'Tingri'),
#  (370780, 191613, 9, '変異'),
#  (370952, 191613, 4, '前'),
#  (371701, 191613, 4, '水 ＴＥＭＰＬＥ ユニバーサル'),
#  (373566, 191613, 2, '『82.99 F.M』'),
#  (374329, 191613, 5, 'Megaflora'),
#  (374927, 191613, 1, 'FLOWS'),
#  (381477, 191613, 5, '水野 亜美AMY'),
#  (382702, 191613, 1, 'SHORELINE'),
#  (384028, 191613, 1, "C'est La Vie"),
#  (387982, 191613, 5, 'Ghost'),
#  (388324, 191613, 4, 'Mouth Dreams (Extro)'),
#  (388677, 191613, 6, 'RAP'),
#  (391192, 191613, 1, '恢复'),
#  (393199, 191613, 1, 'altered reality'),
#  (394794, 191613, 6, 'Princess Daisy'),
#  (398072, 191613, 1, '自分のタッチ'),
#  (398148, 191613, 1, 'Inside The Sphere'),
#  (399278, 191613, 3, '我愛你'),
#  (399865, 191613, 7, '感覚変更'),
#  (402822, 191613, 4, 'Frozen Flame'),
#  (407155, 191613, 3, 'Thank You'),
#  (415171, 191613, 5, '向こう側'),
#  (416706, 191613, 7, '真実の恋'),
#  (419387, 191613, 1, 'Satisfy'),
#  (420441, 191613, 7, 'Joining'),
#  (424062, 191613, 1, 'Suenos Bravos'),
#  (429400, 191613, 3, 'Hit The Spot'),
#  (434380, 191613, 3, 'ブラー'),
#  (441598, 191613, 3, 'Larme à gauche'),
#  (444537, 191613, 1, '悲哀'),
#  (451378, 191613, 2, 'Catarata'),
#  (454105, 191613, 1, 'Embarcadero'),
#  (459275, 191613, 3, 'On a Rolling Sea'),
#  (460237, 191613, 6, 'Dial Up'),
#  (461855, 191613, 4, 'ECCOJAMC1'),
#  (462206, 191613, 6, '私はあなたを永遠に愛します'),
#  (462238, 191613, 5, 'Madrugada'),
#  (464956, 191613, 2, 'High-Tech Low-Life'),
#  (465021, 191613, 1, 'Neon Kitchen'),
#  (468290, 191613, 4, '恐れない'),
#  (468885, 191613, 3, 'A1'),
#  (469922, 191613, 1, 'Last Dance Of The Night'),
#  (471106, 191613, 2, 'Lifetime'),
#  (474579, 191613, 1, 'Conflict Minerals'),
#  (478317, 191613, 1, 'Ghost'),
#  (480035, 191613, 6, 'Curves'),
#  (485305, 191613, 1, 'Be Home Free'),
#  (487706, 191613, 4, 'My Machine'),
#  (488448, 191613, 1, 'New Machines'),
#  (489631, 191613, 5, 'B:/ Infinite Login'),
#  (490038, 191613, 5, 'Dreamcast'),
#  (496036, 191613, 4, 'Eyes Of The Temple'),
#  (499092, 191613, 1, 'Pyxis'),
#  (500508, 191613, 6, '恋人の高い'),
#  (500558, 191613, 1, 'Return of Dreams'),
#  (502351, 191613, 1, '空に光'),
#  (502942, 191613, 5, 'Loving Is Easy'),
#  (507132, 191613, 5, '早朝'),
#  (511206, 191613, 1, 'cruiser'),
#  (511574, 191613, 3, 'Eco Zones'),
#  (511975, 191613, 2, 'STREET ROMANCE 2049'),
#  (515158, 191613, 9, 'OG!'),
#  (518961, 191613, 1, '3rD Best'),
#  (521488, 191613, 6, '見送る'),
#  (524100, 191613, 4, '別の日の気持ち'),
#  (529874, 191613, 5, 'All That'),
#  (532875, 191613, 3, 'Big Gulp'),
#  (533140, 191613, 3, '新しい日の誕生'),
#  (535456, 191613, 2, 'あなたと私'),
#  (544052, 191613, 5, 'シアン水面'),
#  (552805, 191613, 1, 'Soft heat'),
#  (552859, 191613, 5, '愛の瞬間'),
#  (552989, 191613, 2, 'HUNNIDDOLLA'),
#  (556527, 191613, 1, '夢の無限'),
#  (558613, 191613, 7, 'Favorite Places'),
#  (559019, 191613, 3, 'HEAVY'),
#  (564495, 191613, 4, 'totally rad'),
#  (564636, 191613, 4, 'Slow Drip'),
#  (565116, 191613, 1, 'Untitled²'),
#  (566147, 191613, 2, 'Neo Spa & Salon'),
#  (568263, 191613, 3, 'Intro'),
#  (569644, 191613, 1, 'Around'),
#  (571417, 191613, 1, '信仰'),
#  (572248, 191613, 1, 'Hiraeth V'),
#  (573979, 191613, 7, 'ＦＥＥＬＩＮＧ ブルー'),
#  (580439, 191613, 1, 'Glow'),
#  (580970, 191613, 1, '私を愛して Love Me'),
#  (582550, 191613, 1, 'all night'),
#  (583221, 191613, 3, 'Fire and Light'),
#  (584960, 191613, 2, '交差点'),
#  (585539, 191613, 3, 'セックスファンタジー'),
#  (586579, 191613, 2, 'ライブラリ'),
#  (586632, 191613, 3, 'Untitled'),
#  (590430, 191613, 1, 'Fantasy Mind'),
#  (592618, 191613, 5, 'あなたのビジョン'),
#  (593749, 191613, 1, 'Climbing The Corporate Ladder'),
#  (596329, 191613, 7, 'Healing'),
#  (597084, 191613, 2, 'RedVelvetSofa'),
#  (599276, 191613, 1, 'to new york with love'),
#  (601820, 191613, 1, 'Window'),
#  (603318, 191613, 1, 'Macintosh Plus 2k17'),
#  (606623, 191613, 1, 'A Love Story'),
#  (607801, 191613, 2, 'GLOBES'),
#  (607837, 191613, 1, "86' Bonnie and Clyde/Pink Velvet"),
#  (612068, 191613, 4, 'Metamorphosis'),
#  (614963, 191613, 2, 'Fun Tonight'),
#  (617404, 191613, 1, 'OCEAN BREEZE'),
#  (621648, 191613, 2, 'Menneskeforbruger'),
#  (623663, 191613, 2, 'Island Sunrise'),
#  (624921, 191613, 1, 'STREETSX VACATION BIBLE SCHOOL'),
#  (625232, 191613, 4, '終わりと始まり'),
#  (626200, 191613, 4, '恢复'),
#  (631391, 191613, 6, 'ナイトクラブ'),
#  (634142, 191613, 1, 'exolution'),
#  (641444, 191613, 3, 'Hong Kong 2046'),
#  (649358, 191613, 4, 'P.C.'),
#  (650829, 191613, 4, 'アストラルセックス'),
#  (652301, 191613, 1, 'Tripping Over Air'),
#  (654345, 191613, 5, '二'),
#  (657111, 191613, 1, 'enjoy yourself'),
#  (658074, 191613, 4, 'Now And Forever'),
#  (660802, 191613, 1, 'Bluelight specials going on now!'),
#  (662856, 191613, 5, 'summer night'),
#  (665401, 191613, 1, 'Forbidden Fruit'),
#  (668464, 191613, 3, '蒸気涙'),
#  (668775, 191613, 1, '再会'),
#  (669121, 191613, 1, 'IBM Lotus Night'),
#  (676952, 191613, 1, 'Chicago'),
#  (677527, 191613, 1, 'Mirror Mirror'),
#  (679298, 191613, 5, 'Eccojam A3'),
#  (693850, 191613, 7, 'Aqua Domain'),
#  (696399, 191613, 1, 'College Kill Dream'),
#  (696892, 191613, 8, '柔らかい唇'),
#  (699058, 191613, 1, '地下自然公園 Underground Nature Park (feat. 猫 シ Corp.)'),
#  (701018, 191613, 1, '数学'),
#  (701038, 191613, 5, 'Ammonia Clouds'),
#  (702038, 191613, 3, 'Welcome 2 Unknown Death'),
#  (711123, 191613, 1, 'CORE'),
#  (711445, 191613, 4, 'miss you'),
#  (717924, 191613, 1, 'Macintosh Plus Floral Shoppe'),
#  (724287, 191613, 2, '『82.99 F.M』'),
#  (725361, 191613, 2, 'Long Road Home'),
#  (727337, 191613, 3, 'Hesitation'),
#  (730308, 191613, 4, 'Gunshots'),
#  (731114, 191613, 6, '深夜の愛'),
#  (731655, 191613, 1, '東京の夜'),
#  (731912, 191613, 5, '一緒に私たちはスタンド'),
#  (734507, 191613, 1, 'nagisa'),
#  (735421, 191613, 1, 'Perfect Blue'),
#  (743184, 191613, 5, "We've Started Up"),
#  (743354, 191613, 3, '植生'),
#  (746044, 191613, 2, 'Win2Drug'),
#  (751682, 191613, 7, 'B:/ Start Up'),
#  (758593, 191613, 7, '心を入力して'),
#  (764403, 191613, 1, 'starlight'),
#  (764954, 191613, 5, 'Gatorade'),
#  (767680, 191613, 1, 'sweetwine'),
#  (771429, 191613, 5, '一緒に私たちは、市内の遺跡を歩く'),
#  (772052, 191613, 4, 'CD Player pt III'),
#  (774189, 191613, 3, '深夜の願い'),
#  (778247, 191613, 1, 'mustang'),
#  (779634, 191613, 3, 'Decay'),
#  (781883, 191613, 3, '結末'),
#  (782239, 191613, 1, 'Dystopian Mall'),
#  (782943, 191613, 1, 'sunset express {to eternal bliss}'),
#  (783119, 191613, 3, 'OVER U'),
#  (784268, 191613, 3, '手をつないで'),
#  (785148, 191613, 5, '夢は継続さ'),
#  (786268, 191613, 1, '내 마음은 떨고'),
#  (788709, 191613, 1, 'Newsgroup'),
#  (790614, 191613, 5, '美しい沈黙'),
#  (791529, 191613, 1, 'テレパシー'),
#  (792770, 191613, 3, 'Sun'),
#  (794785, 191613, 6, 'COMPUTER HEALING'),
#  (796824, 191613, 4, '昇天'),
#  (802726, 191613, 3, 'Your Move'),
#  (807130, 191613, 2, '月乃 うさぎSERENA'),
#  (808428, 191613, 2, 'Hit Parade')]
