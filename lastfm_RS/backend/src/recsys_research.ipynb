# %%
from constants import *
from sqlalchemy import create_engine, inspect, text, func, MetaData, select, Table
from sqlalchemy.orm import sessionmaker

db = create_engine(
    "postgresql://alumnodb:alumnodb@localhost:5432/lastfm_db", client_encoding="UTF-8")

metadata = MetaData()
metadata.reflect(bind=db)

# %%
def table(name) -> Table:
    return metadata.tables[name]

Tag = table('tag')
Album = table('album')
Artist = table('artist')
Track = table('track')
User = table('user_')

AlbumTags = table('albumtoptags')
ArtistTags = table('artisttoptags')
TrackTags = table('tracktoptags')
UserTags = table('usertoptracks') # Empty, use most frequent?

UserTopAlbums = table('usertopalbums')
UserTopArtists = table('usertopartists')
UserTopTracks = table('usertoptracks')

UserRecentTracks = table('userrecenttracks')
UserLovedTracks = table('userlovedtracks')

# %%
session = sessionmaker(db)

"""
select * from tracktoptags tt join track on track.id = tt.track_id join tag on tag.id = tt.tag_id where tag.name ilike 'rock' order by track.id;
"""
with session.begin() as s:
    display(s.query(TrackTags, Track.c.name)
            .join(Tag, Tag.c.id == TrackTags.c.tag_id)
            .join(Track, Track.c.id == TrackTags.c.track_id)
            .filter(Tag.c.name.ilike('vaporwave'))
            .order_by(Track.c.id).all())
# Out:
# [(402, 191613, 'METAMATERIAL'),
#  (2538, 191613, 'Come Back Down'),
#  (4120, 191613, '発見'),
#  (4539, 191613, '上昇'),
#  (6302, 191613, 'あなたと一人で数分'),
#  (9765, 191613, 'Warmpop'),
#  (10821, 191613, 'Gonna Dream 2nite.'),
#  (10829, 191613, 'Ecco Chamber'),
#  (11415, 191613, 'Better'),
#  (11523, 191613, '着物'),
#  (12124, 191613, 'Beam of Love'),
#  (13812, 191613, 'James Joint'),
#  (14444, 191613, 'Otra Noche en Miami'),
#  (19642, 191613, "Can't You See"),
#  (20054, 191613, '熱帯雨林 Plaza'),
#  (23754, 191613, 'いつも'),
#  (31485, 191613, '痴心妄想'),
#  (36811, 191613, 'バウンス家の中でセックス'),
#  (41632, 191613, '銀'),
#  (41884, 191613, 'KΞΞP/////THIS/////'),
#  (45684, 191613, 'The Setup'),
#  (62806, 191613, 'Bow Ecco'),
#  (69439, 191613, 'ＴＥＭＰＴＡＴＩＯＮ 私はあなたが欲しいんだよ'),
#  (70692, 191613, 'PURITY BOYS'),
#  (73881, 191613, 'Miss Macross'),
#  (74206, 191613, 'chinese food takeaway'),
#  (75726, 191613, 'Resonance'),
#  (75996, 191613, 'Iced Cooly Beatnik'),
#  (76551, 191613, 'Before The Rain'),
#  (80942, 191613, 'Hush'),
#  (84585, 191613, '水TEMPLES'),
#  (86782, 191613, '遠くの愛好家'),
#  (88805, 191613, 'Nine-rubber Wisdom'),
#  (91339, 191613, 'She'),
#  (91666, 191613, 'StayTheNight'),
#  (91701, 191613, 'Saturday Night'),
#  (93901, 191613, '東京，  ２０８９'),
#  (94462, 191613, 'Skylar Spence'),
#  (96235, 191613, 'Metal Rain'),
#  (101150, 191613, 'Private Caller'),
#  (101871, 191613, 'あなたは私の空想です'),
#  (103864, 191613, 'Hit The Spot'),
#  (108556, 191613, 'Occasional Flames'),
#  (111223, 191613, 'mall madness'),
#  (113111, 191613, '表面張力'),
#  (117072, 191613, 'daydream'),
#  (120768, 191613, 'Vaping in the Hood'),
#  (125965, 191613, "Luxury's Fortune"),
#  (129618, 191613, 'C3L3STIAL_CITY'),
#  (135652, 191613, '遠い思い出'),
#  (138115, 191613, 'ブート'),
#  (140084, 191613, 'ハーモニー'),
#  (141066, 191613, 'あなたは私の心にいつもしている'),
#  (153263, 191613, 'Horsey (feat. Sarah Bonito)'),
#  (156010, 191613, '海側恋人'),
#  (157599, 191613, 'Breezem Out'),
#  (157711, 191613, 'パーティーの日！'),
#  (161444, 191613, 'Together'),
#  (162020, 191613, 'Horsey (feat. Sarah Bonito)'),
#  (165528, 191613, 'テレコミュニケーション'),
#  (165536, 191613, '親密'),
#  (176757, 191613, 'The Law'),
#  (179537, 191613, 'Night In Tokyo Pt. II'),
#  (185585, 191613, 'RotatingBed'),
#  (185736, 191613, 'Lipslap'),
#  (188144, 191613, 'アトラクション'),
#  (188351, 191613, 'あなたを待って'),
#  (190198, 191613, 'Teen Pregnancy'),
#  (190797, 191613, 'Cherry Pepsi'),
#  (195283, 191613, '808 Dreams'),
#  (195354, 191613, 'Out of Time'),
#  (198496, 191613, 'shadows'),
#  (201693, 191613, 'Count What You Have Now'),
#  (204787, 191613, 'Lost But Never Alone'),
#  (205410, 191613, '午後11時 The 11pm'),
#  (207871, 191613, 'DAM! DAM! DAM!'),
#  (211547, 191613, 'midnight'),
#  (211903, 191613, 'Private Caller'),
#  (214059, 191613, 'Beach Walk'),
#  (216483, 191613, 'On The Way Out'),
#  (216537, 191613, '表面の下に愛'),
#  (216789, 191613, 'Wake Up'),
#  (218566, 191613, '心合成'),
#  (220074, 191613, '真の姿'),
#  (221875, 191613, '5D'),
#  (223876, 191613, '再びお会い'),
#  (224665, 191613, 'DUFF HUSTER'),
#  (227188, 191613, 'ECCOと悪寒ダイビング'),
#  (230715, 191613, '真正的爱情'),
#  (231740, 191613, 'naga - SHES DIFFERENT IN FLASH'),
#  (233082, 191613, 'Bitter Turns To Sugar'),
#  (234714, 191613, '孤独な夜'),
#  (234789, 191613, '終わりのない愛'),
#  (236862, 191613, '花の専門店'),
#  (239090, 191613, 'HOTEL TAIWAN WELC☯MES U'),
#  (242058, 191613, 'WAVESTEP'),
#  (242655, 191613, 'Loft バルコニー'),
#  (246616, 191613, '停電'),
#  (247002, 191613, 'リサフランク420 / 現代のコンピュー'),
#  (247606, 191613, 'Emerald Hill Zone 2'),
#  (249398, 191613, '最後の抱擁'),
#  (251223, 191613, 'A4'),
#  (253632, 191613, 'Somber Waves'),
#  (255709, 191613, 'ふわっと'),
#  (257987, 191613, 'Nobody Here'),
#  (258652, 191613, 'Hit Vibes'),
#  (259656, 191613, 'Aerobic Workout 95'),
#  (261043, 191613, 'Options'),
#  (264316, 191613, 'Deep Swim'),
#  (272659, 191613, '愛の多くの顔'),
#  (272765, 191613, '新宿ゴールデン街'),
#  (272983, 191613, 'AKAIWA 1985'),
#  (276226, 191613, 'Us'),
#  (276332, 191613, 'Contagious'),
#  (283150, 191613, "ain't nobody like you"),
#  (289529, 191613, 'あなたの世界'),
#  (296137, 191613, 'Fun Tonight'),
#  (296532, 191613, "I'm That Guy"),
#  (298929, 191613, "Pretty Girls i Don't Know Anymore"),
#  (304601, 191613, 'Midnight Caller'),
#  (305838, 191613, '輝き'),
#  (305922, 191613, 'Misery Loves'),
#  (306757, 191613, 'pizza day'),
#  (310776, 191613, 'Bez ciśnień - Lech Music 2020'),
#  (311324, 191613, '星間性交'),
#  (311869, 191613, 'Cerulean'),
#  (312731, 191613, 'SAINT PEPSI - ENJOY YOURSELF'),
#  (312815, 191613, '私はあなたのことを思っている'),
#  (314049, 191613, 'LSD Polyphony'),
#  (314639, 191613, 'NAKANO BOTANICAL GARDENS'),
#  (315408, 191613, 'SimpsonWave1995'),
#  (320980, 191613, '遠くの愛好家'),
#  (321840, 191613, 'Beat Street'),
#  (327531, 191613, 'プランジ'),
#  (330308, 191613, 'いつもそこに私のために'),
#  (331690, 191613, '存在'),
#  (332142, 191613, 'Lost Dreams'),
#  (332728, 191613, 'leo'),
#  (335373, 191613, 'Freeze'),
#  (336605, 191613, 'Implanted Memories'),
#  (339139, 191613, "Don't Kiss Me While i'm Swimming"),
#  (342788, 191613, 'Anxiety Online !'),
#  (346922, 191613, '断線'),
#  (350662, 191613, 'Give It to Me'),
#  (351006, 191613, 'あなたを残す'),
#  (356824, 191613, 'island'),
#  (360784, 191613, 'BIOS'),
#  (363850, 191613, '50//50'),
#  (366787, 191613, '光る目'),
#  (367857, 191613, 'Tingri'),
#  (370780, 191613, '変異'),
#  (370952, 191613, '前'),
#  (371701, 191613, '水 ＴＥＭＰＬＥ ユニバーサル'),
#  (373566, 191613, '『82.99 F.M』'),
#  (374329, 191613, 'Megaflora'),
#  (374927, 191613, 'FLOWS'),
#  (381477, 191613, '水野 亜美AMY'),
#  (382702, 191613, 'SHORELINE'),
#  (384028, 191613, "C'est La Vie"),
#  (387982, 191613, 'Ghost'),
#  (388324, 191613, 'Mouth Dreams (Extro)'),
#  (388677, 191613, 'RAP'),
#  (391192, 191613, '恢复'),
#  (393199, 191613, 'altered reality'),
#  (394794, 191613, 'Princess Daisy'),
#  (398072, 191613, '自分のタッチ'),
#  (398148, 191613, 'Inside The Sphere'),
#  (399278, 191613, '我愛你'),
#  (399865, 191613, '感覚変更'),
#  (402822, 191613, 'Frozen Flame'),
#  (407155, 191613, 'Thank You'),
#  (415171, 191613, '向こう側'),
#  (416706, 191613, '真実の恋'),
#  (419387, 191613, 'Satisfy'),
#  (420441, 191613, 'Joining'),
#  (424062, 191613, 'Suenos Bravos'),
#  (429400, 191613, 'Hit The Spot'),
#  (434380, 191613, 'ブラー'),
#  (441598, 191613, 'Larme à gauche'),
#  (444537, 191613, '悲哀'),
#  (451378, 191613, 'Catarata'),
#  (454105, 191613, 'Embarcadero'),
#  (459275, 191613, 'On a Rolling Sea'),
#  (460237, 191613, 'Dial Up'),
#  (461855, 191613, 'ECCOJAMC1'),
#  (462206, 191613, '私はあなたを永遠に愛します'),
#  (462238, 191613, 'Madrugada'),
#  (464956, 191613, 'High-Tech Low-Life'),
#  (465021, 191613, 'Neon Kitchen'),
#  (468290, 191613, '恐れない'),
#  (468885, 191613, 'A1'),
#  (469922, 191613, 'Last Dance Of The Night'),
#  (471106, 191613, 'Lifetime'),
#  (474579, 191613, 'Conflict Minerals'),
#  (478317, 191613, 'Ghost'),
#  (480035, 191613, 'Curves'),
#  (485305, 191613, 'Be Home Free'),
#  (487706, 191613, 'My Machine'),
#  (488448, 191613, 'New Machines'),
#  (489631, 191613, 'B:/ Infinite Login'),
#  (490038, 191613, 'Dreamcast'),
#  (496036, 191613, 'Eyes Of The Temple'),
#  (499092, 191613, 'Pyxis'),
#  (500508, 191613, '恋人の高い'),
#  (500558, 191613, 'Return of Dreams'),
#  (502351, 191613, '空に光'),
#  (502942, 191613, 'Loving Is Easy'),
#  (507132, 191613, '早朝'),
#  (511206, 191613, 'cruiser'),
#  (511574, 191613, 'Eco Zones'),
#  (511975, 191613, 'STREET ROMANCE 2049'),
#  (515158, 191613, 'OG!'),
#  (518961, 191613, '3rD Best'),
#  (521488, 191613, '見送る'),
#  (524100, 191613, '別の日の気持ち'),
#  (529874, 191613, 'All That'),
#  (532875, 191613, 'Big Gulp'),
#  (533140, 191613, '新しい日の誕生'),
#  (535456, 191613, 'あなたと私'),
#  (544052, 191613, 'シアン水面'),
#  (552805, 191613, 'Soft heat'),
#  (552859, 191613, '愛の瞬間'),
#  (552989, 191613, 'HUNNIDDOLLA'),
#  (556527, 191613, '夢の無限'),
#  (558613, 191613, 'Favorite Places'),
#  (559019, 191613, 'HEAVY'),
#  (564495, 191613, 'totally rad'),
#  (564636, 191613, 'Slow Drip'),
#  (565116, 191613, 'Untitled²'),
#  (566147, 191613, 'Neo Spa & Salon'),
#  (568263, 191613, 'Intro'),
#  (569644, 191613, 'Around'),
#  (571417, 191613, '信仰'),
#  (572248, 191613, 'Hiraeth V'),
#  (573979, 191613, 'ＦＥＥＬＩＮＧ ブルー'),
#  (580439, 191613, 'Glow'),
#  (580970, 191613, '私を愛して Love Me'),
#  (582550, 191613, 'all night'),
#  (583221, 191613, 'Fire and Light'),
#  (584960, 191613, '交差点'),
#  (585539, 191613, 'セックスファンタジー'),
#  (586579, 191613, 'ライブラリ'),
#  (586632, 191613, 'Untitled'),
#  (590430, 191613, 'Fantasy Mind'),
#  (592618, 191613, 'あなたのビジョン'),
#  (593749, 191613, 'Climbing The Corporate Ladder'),
#  (596329, 191613, 'Healing'),
#  (597084, 191613, 'RedVelvetSofa'),
#  (599276, 191613, 'to new york with love'),
#  (601820, 191613, 'Window'),
#  (603318, 191613, 'Macintosh Plus 2k17'),
#  (606623, 191613, 'A Love Story'),
#  (607801, 191613, 'GLOBES'),
#  (607837, 191613, "86' Bonnie and Clyde/Pink Velvet"),
#  (612068, 191613, 'Metamorphosis'),
#  (614963, 191613, 'Fun Tonight'),
#  (617404, 191613, 'OCEAN BREEZE'),
#  (621648, 191613, 'Menneskeforbruger'),
#  (623663, 191613, 'Island Sunrise'),
#  (624921, 191613, 'STREETSX VACATION BIBLE SCHOOL'),
#  (625232, 191613, '終わりと始まり'),
#  (626200, 191613, '恢复'),
#  (631391, 191613, 'ナイトクラブ'),
#  (634142, 191613, 'exolution'),
#  (641444, 191613, 'Hong Kong 2046'),
#  (649358, 191613, 'P.C.'),
#  (650829, 191613, 'アストラルセックス'),
#  (652301, 191613, 'Tripping Over Air'),
#  (654345, 191613, '二'),
#  (657111, 191613, 'enjoy yourself'),
#  (658074, 191613, 'Now And Forever'),
#  (660802, 191613, 'Bluelight specials going on now!'),
#  (662856, 191613, 'summer night'),
#  (665401, 191613, 'Forbidden Fruit'),
#  (668464, 191613, '蒸気涙'),
#  (668775, 191613, '再会'),
#  (669121, 191613, 'IBM Lotus Night'),
#  (676952, 191613, 'Chicago'),
#  (677527, 191613, 'Mirror Mirror'),
#  (679298, 191613, 'Eccojam A3'),
#  (693850, 191613, 'Aqua Domain'),
#  (696399, 191613, 'College Kill Dream'),
#  (696892, 191613, '柔らかい唇'),
#  (699058, 191613, '地下自然公園 Underground Nature Park (feat. 猫 シ Corp.)'),
#  (701018, 191613, '数学'),
#  (701038, 191613, 'Ammonia Clouds'),
#  (702038, 191613, 'Welcome 2 Unknown Death'),
#  (711123, 191613, 'CORE'),
#  (711445, 191613, 'miss you'),
#  (717924, 191613, 'Macintosh Plus Floral Shoppe'),
#  (724287, 191613, '『82.99 F.M』'),
#  (725361, 191613, 'Long Road Home'),
#  (727337, 191613, 'Hesitation'),
#  (730308, 191613, 'Gunshots'),
#  (731114, 191613, '深夜の愛'),
#  (731655, 191613, '東京の夜'),
#  (731912, 191613, '一緒に私たちはスタンド'),
#  (734507, 191613, 'nagisa'),
#  (735421, 191613, 'Perfect Blue'),
#  (743184, 191613, "We've Started Up"),
#  (743354, 191613, '植生'),
#  (746044, 191613, 'Win2Drug'),
#  (751682, 191613, 'B:/ Start Up'),
#  (758593, 191613, '心を入力して'),
#  (764403, 191613, 'starlight'),
#  (764954, 191613, 'Gatorade'),
#  (767680, 191613, 'sweetwine'),
#  (771429, 191613, '一緒に私たちは、市内の遺跡を歩く'),
#  (772052, 191613, 'CD Player pt III'),
#  (774189, 191613, '深夜の願い'),
#  (778247, 191613, 'mustang'),
#  (779634, 191613, 'Decay'),
#  (781883, 191613, '結末'),
#  (782239, 191613, 'Dystopian Mall'),
#  (782943, 191613, 'sunset express {to eternal bliss}'),
#  (783119, 191613, 'OVER U'),
#  (784268, 191613, '手をつないで'),
#  (785148, 191613, '夢は継続さ'),
#  (786268, 191613, '내 마음은 떨고'),
#  (788709, 191613, 'Newsgroup'),
#  (790614, 191613, '美しい沈黙'),
#  (791529, 191613, 'テレパシー'),
#  (792770, 191613, 'Sun'),
#  (794785, 191613, 'COMPUTER HEALING'),
#  (796824, 191613, '昇天'),
#  (802726, 191613, 'Your Move'),
#  (807130, 191613, '月乃 うさぎSERENA'),
#  (808428, 191613, 'Hit Parade')]
